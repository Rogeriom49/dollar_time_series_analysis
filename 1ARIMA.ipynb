# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error,mean_absolute_percentage_error,r2_score
from pmdarima import auto_arima
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('datasets/Ibovespa14anos.csv')
display(df.head(5))
# Out:
#           Data   Último  Abertura   Máxima   Mínima    Vol.    Var%
# 0   24.05.2024  124.306   124.731  125.257  124.259   9,21M  -0,34%
# 1   23.05.2024  124.729   125.650  125.665  124.431   9,99M  -0,73%
# 2   22.05.2024  125.650   127.412  127.412  125.524  12,40M  -1,38%
# 3   21.05.2024  127.412   127.754  128.272  127.205   9,14M  -0,27%
# 4   20.05.2024  127.751   128.151  128.730  127.488   9,34M  -0,31%
# 5   17.05.2024  128.151   128.280  128.464  127.696  10,26M  -0,10%
# 6   16.05.2024  128.284   128.029  128.965  127.922   9,86M   0,20%
# 7   15.05.2024  128.028   128.514  128.646  127.029  10,86M  -0,38%
# 8   14.05.2024  128.515   128.155  128.965  127.962  11,89M   0,28%
# 9   13.05.2024  128.155   127.600  128.669  127.599   8,92M   0,44%
# 10  10.05.2024  127.600   128.188  129.022  127.467  12,57M  -0,46%
# 11  09.05.2024  128.188   129.468  129.468  127.376  13,37M  -1,00%
# 12  08.05.2024  129.481   129.210  129.564  128.048   9,79M   0,21%
# 13  07.05.2024  129.210   128.466  129.745  128.464  10,18M   0,58%
# 14  06.05.2024  128.466   128.506  129.181  128.294   8,78M  -0,03%
# 15  03.05.2024  128.509   127.130  128.787  127.130  12,80M   1,09%
# 16  02.05.2024  127.122   125.926  127.670  125.926  11,55M   0,95%
# 17  30.04.2024  125.924   127.352  127.352  125.856  10,89M  -1,12%
# 18  29.04.2024  127.352   126.527  127.352  126.467   8,39M   0,65%
# 19  26.04.2024  126.526   124.651  126.826  124.651   8,90M   1,51%

# %%
# Selecionando apenas as colunas Data e Último
df_data = df[['Data','Último']]

# %%
df_data.head()
# Out:
#          Data   Último
# 0  24.05.2024  124.306
# 1  23.05.2024  124.729
# 2  22.05.2024  125.650
# 3  21.05.2024  127.412
# 4  20.05.2024  127.751

# %%
# Renomeando as colunas para padronização
df_data.rename(columns={'Data':'ds','Último':'y'},inplace=True)

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3566 entries, 0 to 3565
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ds      3566 non-null   object
#  1   y       3566 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 55.8+ KB

# %%
df_data['ds'] = pd.to_datetime(df_data['ds'])

# %%
df_data.set_index('ds', inplace=True)

# %%
model = auto_arima(df_data['y'], seasonal=False, trace=True)
print(model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=11257.128, Time=2.77 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=11292.057, Time=0.06 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=11273.139, Time=0.14 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=11274.242, Time=0.19 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=11290.652, Time=0.05 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=11274.490, Time=0.81 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=11272.362, Time=1.51 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=11259.085, Time=3.20 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=11278.125, Time=1.20 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=11273.818, Time=0.60 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=11268.306, Time=2.07 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=11266.263, Time=1.66 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=11259.277, Time=4.69 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=11255.787, Time=1.12 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=11273.135, Time=0.39 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=11270.870, Time=0.73 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=11257.748, Time=1.47 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=11276.770, Time=0.69 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=11272.496, Time=0.23 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=11266.940, Time=1.04 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=11264.899, Time=0.72 sec
#  ARIMA(3,1,3)(0,0,0)[0]             : AIC=11257.796, Time=1.84 sec
#
# Best model:  ARIMA(2,1,2)(0,0,0)[0]
# Total fit time: 27.241 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 3566
# Model:               SARIMAX(2, 1, 2)   Log Likelihood               -5622.893
# Date:                Mon, 11 Nov 2024   AIC                          11255.787
# Time:                        19:17:33   BIC                          11286.681
# Sample:                             0   HQIC                         11266.802
#                                - 3566
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.5502      0.043    -36.463      0.000      -1.633      -1.467
# ar.L2         -0.7301      0.043    -17.002      0.000      -0.814      -0.646
# ma.L1          1.4824      0.048     31.033      0.000       1.389       1.576
# ma.L2          0.6550      0.049     13.419      0.000       0.559       0.751
# sigma2         1.3725      0.015     93.730      0.000       1.344       1.401
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):             16882.14
# Prob(Q):                              0.91   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.25   Skew:                             0.88
# Prob(H) (two-sided):                  0.00   Kurtosis:                        13.52
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
def arima_forecast(history):
    model = ARIMA(history, order=(2,1,2))
    model_fit = model.fit()
    output = model_fit.forecast()
    yhat = output[0]
    return yhat

# %%
X = df_data.values
size = int(len(X) * 0.8)
train, test = X[0:size], X[size:len(X)]

# %%
history = [x for x in train]
predictions = list()
for t in range(len(test)):
    yhat = arima_forecast(history)
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)

# %%
plt.figure(figsize=(12, 6), dpi=100)
plt.plot(df_data.iloc[size:,:].index, test, label='True')
plt.plot(df_data.iloc[size:,:].index, predictions, color='red', label='Predict')
plt.title('Predict vs True')
plt.xlabel('Data')
plt.ylabel('Ultimo')
plt.legend()
plt.show()

# %%
r2 = r2_score(test, predictions)
mae = mean_absolute_error(test, predictions)
mse =mean_squared_error(test, predictions)
print(f"R2: {r2.round(2)*100}%")
print(f"MAE: {mae.round(2)*100}%")
print(f"MSE: {mse.round(2)*100}%")
# Out:
# R2: 98.0%
# MAE: 66.0%
# MSE: 74.0%
